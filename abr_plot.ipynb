# %%
import numpy as np
import os
from dopamine.agents.dqn import dqn_agent
from dopamine.discrete_domains import run_experiment
from dopamine.colab import utils as colab_utils
from absl import flags
import gin.tf

# %%
base_path = "abr_test_logs/dopamine"

# %%
# @title Load the training logs.
random_dqn_data = colab_utils.read_experiment(
    base_path, verbose=True, summary_keys=['train_episode_returns'])
random_dqn_data['agent'] = 'MyRandomDQN'
random_dqn_data['run_number'] = 1
print(random_dqn_data)
# Out:
# Reading statistics from: abr_test_logs/dopamine//logs/log_9
#    iteration  train_episode_returns        agent  run_number
# 0        0.0            -318.153823  MyRandomDQN           1
# 1        1.0             311.746418  MyRandomDQN           1
# 2        2.0             231.877342  MyRandomDQN           1
# 3        3.0             -15.179949  MyRandomDQN           1
# 4        4.0             269.245601  MyRandomDQN           1
# 5        5.0             324.429954  MyRandomDQN           1
# 6        6.0             197.899278  MyRandomDQN           1
# 7        7.0             174.879225  MyRandomDQN           1
# 8        8.0             224.901616  MyRandomDQN           1
# 9        9.0              13.008093  MyRandomDQN           1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,8))
sns.lineplot(data=random_dqn_data, x='iteration', y='train_episode_returns', ax=ax)
plt.title("ABR")
plt.show()

# %%
# Need to look at _run_eval_phase(self, statistics)

# %%
runner = run_experiment.create_runner(base_path, schedule='continuous_train')

# TODO: 
# Figure out how to evaluate agent after training
# Out:
# INFO:tensorflow:Creating TrainRunner ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-843c6ada1804> in <module>
# ----> 1 runner = run_experiment.create_runner(base_path, schedule='continuous_train')
#
# ~/Documents/research_ml/dopamine/dopenv/lib/python3.7/site-packages/gin/config.py in gin_wrapper(*args, **kwargs)
#    1076       scope_info = " in scope '{}'".format(scope_str) if scope_str else ''
#    1077       err_str = err_str.format(name, fn_or_cls, scope_info)
# -> 1078       utils.augment_exception_message_and_reraise(e, err_str)
#    1079
#    1080   return gin_wrapper
#
# ~/Documents/research_ml/dopamine/dopenv/lib/python3.7/site-packages/gin/utils.py in augment_exception_message_and_reraise(exception, message)
#      47   if six.PY3:
#      48     ExceptionProxy.__qualname__ = type(exception).__qualname__
# ...
